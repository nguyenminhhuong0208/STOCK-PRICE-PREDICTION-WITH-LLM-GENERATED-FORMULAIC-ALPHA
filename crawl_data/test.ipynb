# %%
import pandas as pd 
df = pd.read_csv('../data/BID_with_content.csv')
#filer only rows with content length > 1000
df = df[df['content'].str.len() >0]
df.head()
# Out:
#     Unnamed: 0           Thời gian  \
# 12          12  (07/10/2025 07:52)
# 25          25  (25/08/2025 08:08)
# 28          28  (20/08/2025 00:05)
# 31          31  (02/08/2025 09:13)
# 37          37  (02/07/2025 07:03)
#
#                                               Tiêu đề  \
# 12  'Đế chế' của ông Phạm Nhật Vượng chỉ có 37,3% ...
# 25  Công bố 200 doanh nghiệp nộp ngân sách lớn nhấ...
# 28  Lần đầu tiên trong lịch sử Việt Nam có 10 ngân...
# 31  20 doanh nghiệp niêm yết lãi lớn nhất 6T2025: ...
# 37  Cuộc đua vốn hóa 25 năm: Một công ty thủy điện...
#
#                                                   URL  \
# 12  https://cafef.vn/de-che-cua-ong-pham-nhat-vuon...
# 25  https://cafef.vn/cong-bo-200-doanh-nghiep-nop-...
# 28  https://cafef.vn/lan-dau-tien-trong-lich-su-vi...
# 31  https://cafef.vn/20-doanh-nghiep-niem-yet-lai-...
# 37  https://cafef.vn/cuoc-dua-von-hoa-25-nam-mot-c...
#
#                                               content
# ...
