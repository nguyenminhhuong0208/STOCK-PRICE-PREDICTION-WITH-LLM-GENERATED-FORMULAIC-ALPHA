# %%
import pandas as pd 
df = pd.read_csv('../data/CTG_with_content.csv')
#filer only rows with content length > 1000
df = df[df['content'].str.len() >0]
print(df.shape)
df.head()
# Out:
# (30, 5)
#     Unnamed: 0           Thời gian  \
# 5            5  (24/10/2025 07:32)
# 11          11  (07/10/2025 07:52)
# 13          13  (01/10/2025 10:10)
# 20          20  (03/09/2025 13:29)
# 23          23  (27/08/2025 01:03)
#
#                                               Tiêu đề  \
# 5   Những DN lớn nhất: Chỉ Vinamilk và ACV trả lươ...
# 11  'Đế chế' của ông Phạm Nhật Vượng chỉ có 37,3% ...
# 13  VietinBank chốt ngày chi hơn 2.400 tỷ đồng trả...
# 20  VietinBank lên kế hoạch lợi nhuận trước thuế 3...
# 23  Xoá bỏ độc quyền sản xuất vàng miếng, ngân hàn...
#
#                                                   URL  \
# 5   https://cafef.vn/nhung-dn-lon-nhat-chi-vinamil...
# 11  https://cafef.vn/de-che-cua-ong-pham-nhat-vuon...
# 13  https://cafef.vn/vietinbank-chot-ngay-chi-hon-...
# 20  https://cafef.vn/vietinbank-len-ke-hoach-loi-n...
# 23  https://cafef.vn/xoa-bo-doc-quyen-san-xuat-van...
#
#                                               content
# ...
